# %% [markdown]
# **Introduction**
#
# In this work, a basic performance analysis of bowlers in One day Cricket matches have been analyzed (on very basic level), this is a kind of exploratory work, not trying to solve any specific problem, rather trying to getting an insigth about it.
#
# The file source is "ESPN Cricinfo"(https://stats.espncricinfo.com/ci/content/records/283193.html), one of the most followed site for Cricket, there data is trustworthy and alinged with the data of the "ICC", the top most governing body of cricket.
#
# In this EDA (Exploratory Data Analysis), few questions will be tried to answer, which will follow one by one with resutls and the code in the subsequent section.

# %% [markdown]
# **Importing Libraries**
#
# This is the first section of the code, where the necessary library/modules are imported. This import is an iterative process, means if any module seems necessary after writing some portion of codes, then need to comeback here, import that and run the code section again, it is often not possible to find what are the library/modules necessary beforehand.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Q1: Importing and reading the the data file**
#
# In this step, the data file which is analyzed would be read, the file is downloaded from the source in csv format, one of the most common type, and could be read with simple built-in function.
#
# After importing, a simple check is done to make sure the data set is working correctly.

# %%
df = pd.read_csv(r"D:\Data Science\EMK-DPMLP\bowler_most_wickets_ODI.csv")

# %%
display(df) #to check it is done correctly
# Out:
#                           Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0   M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811  12326   534
# 1              Wasim Akram (PAK)  1984-2003  356   351  18186  11812   502
# 2             Waqar Younis (PAK)  1989-2003  262   258  12698   9919   416
# 3           WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775  11014   400
# 4   Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670  13632   395
# ..                           ...        ...  ...   ...    ...    ...   ...
# 72          SR Tendulkar (INDIA)  1989-2012  463   270   8054   6850   154
# 73               BAW Mendis (SL)  2008-2015   87    84   4154   3324   152
# 74             Rashid Khan (AFG)  2015-2022   80    76   4074   2821   151
# 75             UDU Chandana (SL)  1994-2007  147   136   6142   4818   151
# 76              R Ashwin (INDIA)  2010-2022  113   111   6141   5058   151
#
#       Ave  Econ    SR   4   5
# 0   23.08  3.93  35.2  15  10
# ...

# %% [markdown]
# **Q2: Display the first 10 rows of the dataframe**
#
# There is a simple fuction to do so.

# %%
display(df.head(10))
# Out:
#                          Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811  12326   534
# 1             Wasim Akram (PAK)  1984-2003  356   351  18186  11812   502
# 2            Waqar Younis (PAK)  1989-2003  262   258  12698   9919   416
# 3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775  11014   400
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670  13632   395
# 5       SM Pollock (Afr/ICC/SA)  1996-2008  303   297  15712   9631   393
# 6          GD McGrath (AUS/ICC)  1993-2007  250   248  12970   8391   381
# 7                   B Lee (AUS)  2000-2012  221   217  11185   8877   380
# 8               SL Malinga (SL)  2004-2019  226   220  10936   9760   338
# 9         A Kumble (Asia/INDIA)  1990-2007  271   265  14496  10412   337
#
#      Ave  Econ    SR   4   5
# 0  23.08  3.93  35.2  15  10
# 1  23.52  3.89  36.2  17   6
# 2  23.84  4.68  30.5  14  13
# 3  27.53  4.18  39.4   9   4
# ...

# %% [markdown]
# **Q3: Create a markdown cell and explain the meaning of each column**
#
# In jupyter notebook it can be done selecting "Markdown" instead of "Code" from "Menu bar" (have doubt what exacty it is called), or using shortcut. In Google colab, same purpose can be served using the "Add text cells".
#
# Below is the short description of each column.
#
# Player: Name of the Player followed by the country/group/associations they represent in their career which are counted as international matches and for this record.
#
# Span: Time represented as "starting year" to "ending year" between which the mathces have been played. (Q: what if a player is currently playing? to check this the original data source has been visited, and found that, in that case, the current year has been mentioned, but no missing "end year". It is easier in that case as the data set is small and the players playing currently is known, but in case of very big, unorganized data set with little/poor/incorrect description, it might need to take different appraoch to find it.)
#
# Mat: short form of "Matches", means the number of game have been played. (Q; what if a match had been abandoned without bowling a single bowl? No answer found.)
#
# Inns: means "Innings bowled", most probably, if the bowler bowl at least a single bowl in a match is counted as "Inns" (so the question arises in last point is solved here.)
#
# Balls: Number of valid delivery completed by the bowler (excluding all no balls, wide balls, dead balls and other not counted as legal delivery).
#
# Runs: Runs conceded by the bowler (scored by a batsman or awarded as extra like wide). Remember an illegal delivery can cost some runs also.
#
# Wkts: Wicket taken by the bowler (example, run out is not included here as this is not counted as "taken by the bowler").
#
# BBI: Best bowling figure in a single innings. This is sorted accoridng to the highest number of wicket taken, then least run conceded, then number of legal delivery bowled, respectively.
#
# Ave: Bowling average, means the total runs conceded is divided by the total wicket taken in total career (Total Runs Conceded (Column "Runs") / Total number of wickets taken (Column "Wkts")).
#
# Econ: Economy rate, which is defined as the run conceded per over (1 over == 6 balls) according to total career data (Total run conceded (Column "Runs")/ Total number of valid delivery (Column "Balls") * 6).
#
# SR: bowling strike rate, means number of balls needed by this bowler to ball to take a wicket (Total number of ball bowled/Total number of wicket).
#
# 4: Four wickets haul, means number of innings in which the bowler takes 4 or more wickets.
#
# 5: Five wickets haul, means number of innings in which the bowler takes 5 or more wickets.

# %% [markdown]
# **Q4: find the number of rows and columns in the dataframe**
#
# Simple code can serve the purpose as below.

# %%
df.shape # not required actually, can directly run below code as it is understandable that the dataset has only 2 dimension
# Out:
# (77, 12)

# %%
print(f"number of rows in the dataframe = {df.shape[0]}")
print(f"number of columns in the dataframe = {df.shape[1]}")
# Out:
# number of rows in the dataframe = 77
# number of columns in the dataframe = 12

# %% [markdown]
# **Q5: find the data statistics and check for the data types**
#
# Again, simple code is enough to do so.

# %% [markdown]
# Checking data types

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  77 non-null     object
#  1   Span    77 non-null     object
#  2   Mat     77 non-null     int64
#  3   Inns    77 non-null     int64
#  4   Balls   77 non-null     int64
#  5   Runs    77 non-null     int64
#  6   Wkts    77 non-null     int64
#  7   Ave     77 non-null     float64
#  8   Econ    77 non-null     float64
#  9   SR      77 non-null     float64
#  10  4       77 non-null     int64
#  11  5       77 non-null     int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 7.3+ KB
# None

# %% [markdown]
# **Q6: Are there any missing values present in the dataset?**
#
# This question is already answered in the previous section while checking the data type, it is found that, there are 77 entries, and each column also has 77 non-null value. Another way could be as follows.

# %%
df.isnull().sum() # will return total number of null value in each column/feature
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# Balls     0
# Runs      0
# Wkts      0
# Ave       0
# Econ      0
# SR        0
# 4         0
# 5         0
# dtype: int64

# %%
np.where(pd.isnull(df)) #code to find exact location of missing value, it makes replacing those easier.
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# **Q7: Rename the column names appropriately.**
#
# To do so, first the existing column names are checked, then appropriate replacment are chosen which can more accurately describe the data, in some cases the new name could be longer, but it is ok as it will make the data for understandable for others.
#
# Here, a list of old column names has been crated, followed by a list of new column names, (inappropriate or confusing column names are changed), then a dictionary has beed created, which is used to replace the old column name from the data frame. Finally with a simple command the new dataset is checked to make sure the action is completed successfully.

# %%
old_column = df.columns
print(old_column) #just to check it works
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'Balls', 'Runs', 'Wkts', 'Ave', 'Econ',
#        'SR', '4', '5'],
#       dtype='object')

# %%
new_column = ['Player_name (Country)', 'Career_Span', 'Matches_Played', 'Innings_Bowled', 'Balls_bowled', 'Runs_Conceded', 'Wickets_Taken', 'Bowling_Average', 'Economy_Rate',
       'Strike_Rate', '4_Wicket_haul', '5_Wicket_haul']
print(new_column) #just to check it works
# Out:
# ['Player_name (Country)', 'Career_Span', 'Matches_Played', 'Innings_Bowled', 'Balls_bowled', 'Runs_Conceded', 'Wickets_Taken', 'Bowling_Average', 'Economy_Rate', 'Strike_Rate', '4_Wicket_haul', '5_Wicket_haul']

# %%
column_dictionary = dict(zip(old_column, new_column)) #simple code to create a dictionary from two separate list

print(column_dictionary) #just to check it works
# Out:
# {'Player': 'Player_name (Country)', 'Span': 'Career_Span', 'Mat': 'Matches_Played', 'Inns': 'Innings_Bowled', 'Balls': 'Balls_bowled', 'Runs': 'Runs_Conceded', 'Wkts': 'Wickets_Taken', 'Ave': 'Bowling_Average', 'Econ': 'Economy_Rate', 'SR': 'Strike_Rate', '4': '4_Wicket_haul', '5': '5_Wicket_haul'}

# %%
df = df.rename(columns = column_dictionary)
display(df.head()) #just to check it works
# Out:
#           Player_name (Country) Career_Span  Matches_Played  Innings_Bowled  \
# 0  M Muralitharan (Asia/ICC/SL)   1993-2011             350             341
# 1             Wasim Akram (PAK)   1984-2003             356             351
# 2            Waqar Younis (PAK)   1989-2003             262             258
# 3          WPUJC Vaas (Asia/SL)   1994-2008             322             320
# 4  Shahid Afridi (Asia/ICC/PAK)   1996-2015             398             372
#
#    Balls_bowled  Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
#    Strike_Rate  4_Wicket_haul  5_Wicket_haul
# ...

# %% [markdown]
# **Q8: How many players played for ICC?**
#
# Here the problem is, there is no separate column for country, rather it is joined together with player name. So it would be a good idea to separate the Country name from Player name and make two separate column. It is also possibelt to check is "ICC" a part of the string and counting the number of element where ICC is present, it is clumsy sometimes, as the name of a cricketer might contain "ICC" in the string, but here the name of players are appropriately capitalized, so it is possibel to do in this way.

# %%
list_of_Name = df["Player_name (Country)"].to_list()
print(list_of_Name)#to check it is working
# Out:
# ['M Muralitharan (Asia/ICC/SL)', 'Wasim Akram (PAK)', 'Waqar Younis (PAK)', 'WPUJC Vaas (Asia/SL)', 'Shahid Afridi (Asia/ICC/PAK)', 'SM Pollock (Afr/ICC/SA)', 'GD McGrath (AUS/ICC)', 'B Lee (AUS)', 'SL Malinga (SL)', 'A Kumble (Asia/INDIA)', 'ST Jayasuriya (Asia/SL)', 'J Srinath (INDIA)', 'DL Vettori (ICC/NZ)', 'SK Warne (AUS/ICC)', 'Saqlain Mushtaq (PAK)', 'AB Agarkar (INDIA)', 'Shakib Al Hasan (BAN)', 'Z Khan (Asia/INDIA)', 'JH Kallis (Afr/ICC/SA)', 'AA Donald (SA)', 'Mashrafe Mortaza (Asia/BAN)', 'JM Anderson (ENG)', 'Abdul Razzaq (Asia/PAK)', 'Harbhajan Singh (Asia/INDIA)', 'M Ntini (ICC/SA)', 'N Kapil Dev (INDIA)', 'Shoaib Akhtar (Asia/ICC/PAK)', 'KD Mills (NZ)', 'MG Johnson (AUS)', 'HH Streak (Afr/ZIM)', 'D Gough (ENG/ICC)', 'CA Walsh (WI)', 'CEL Ambrose (WI)', 'Abdur Razzak (BAN)', 'CJ McDermott (AUS)', 'CZ Harris (NZ)', 'CL Cairns (ICC/NZ)', 'DJ Bravo (WI)', 'KMDN Kulasekara (SL)', 'DW Steyn (Afr/SA)', 'BKV Prasad (INDIA)', 'MA Starc (AUS)', 'SR Waugh (AUS)', 'CL Hooper (WI)'
# ...

# %%
matchers = ["ICC"] #this is very useful if we want to check multiple substring in a particular list

matching = [s for s in list_of_Name if any(xs in s for xs in matchers)] #creating another list where "ICC" is present.
print (matching) #just a check the result is fine, no unwanted value is present, if the data set is too big, this will not work.

print (len(matching)) #finding the answer.
# Out:
# ['M Muralitharan (Asia/ICC/SL)', 'Shahid Afridi (Asia/ICC/PAK)', 'SM Pollock (Afr/ICC/SA)', 'GD McGrath (AUS/ICC)', 'DL Vettori (ICC/NZ)', 'SK Warne (AUS/ICC)', 'JH Kallis (Afr/ICC/SA)', 'M Ntini (ICC/SA)', 'Shoaib Akhtar (Asia/ICC/PAK)', 'D Gough (ENG/ICC)', 'CL Cairns (ICC/NZ)', 'A Flintoff (ENG/ICC)', 'CH Gayle (ICC/WI)']
# 13

# %%
print (len(matching)) #finding the answer.
# Out:
# 13

# %% [markdown]
# Another way could be rearranging the "Player_name (Country)" column in a way thus it makes the dataset "neat" and extarcting information become easier, in this section, it will be done

# %%
#creating two separate column with player name and the country they represent and replacing the original "Player_name (Country)" Column
df[["Player_Name", "Country"]] = df["Player_name (Country)"].str.split("(", expand=True)
df ["Country"] = df ["Country"].str.replace(")", "")
display(df.head())
# Out:
# <ipython-input-179-ad02f9f094b2>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df ["Country"] = df ["Country"].str.replace(")", "")
#           Player_name (Country) Career_Span  Matches_Played  Innings_Bowled  \
# 0  M Muralitharan (Asia/ICC/SL)   1993-2011             350             341
# 1             Wasim Akram (PAK)   1984-2003             356             351
# 2            Waqar Younis (PAK)   1989-2003             262             258
# 3          WPUJC Vaas (Asia/SL)   1994-2008             322             320
# 4  Shahid Afridi (Asia/ICC/PAK)   1996-2015             398             372
#
#    Balls_bowled  Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0         18811          12326            534            23.08          3.93
# ...

# %%
#now there are two separate column for Player name and Country, original Player name (Country) column can be dropped.
df = df.drop("Player_name (Country)", axis=1)
display(df.head()) #checking the drop works correctly
# Out:
#   Career_Span  Matches_Played  Innings_Bowled  Balls_bowled  Runs_Conceded  \
# 0   1993-2011             350             341         18811          12326
# 1   1984-2003             356             351         18186          11812
# 2   1989-2003             262             258         12698           9919
# 3   1994-2008             322             320         15775          11014
# 4   1996-2015             398             372         17670          13632
#
#    Wickets_Taken  Bowling_Average  Economy_Rate  Strike_Rate  4_Wicket_haul  \
# 0            534            23.08          3.93         35.2             15
# 1            502            23.52          3.89         36.2             17
# 2            416            23.84          4.68         30.5             14
# 3            400            27.53          4.18         39.4              9
# 4            395            34.51          4.62         44.7              4
#
#    5_Wicket_haul      Player_Name       Country
# ...

# %%
#Now rearrange the sequence of column
old_sequence_column = df.columns #create a list of existing column in existing order, which can easily be copied, so in next step writing all column names can be avoided
print (old_sequence_column)
# Out:
# Index(['Career_Span', 'Matches_Played', 'Innings_Bowled', 'Balls_bowled',
#        'Runs_Conceded', 'Wickets_Taken', 'Bowling_Average', 'Economy_Rate',
#        'Strike_Rate', '4_Wicket_haul', '5_Wicket_haul', 'Player_Name',
#        'Country'],
#       dtype='object')

# %%
#paste the output of this command and create a new list, inside the list rearrange the column name, much easier than writing down separately
new_sequence_column = ['Player_Name', 'Country', 'Career_Span', 'Matches_Played', 'Innings_Bowled', 'Balls_bowled', 'Runs_Conceded', 'Wickets_Taken', 'Bowling_Average', 'Economy_Rate', 'Strike_Rate', '4_Wicket_haul', '5_Wicket_haul']

#new dataset replace the old dataset
df = df[new_sequence_column]
display(df.head()) #check the purpose is served
# Out:
#        Player_Name       Country Career_Span  Matches_Played  Innings_Bowled  \
# 0  M Muralitharan    Asia/ICC/SL   1993-2011             350             341
# 1     Wasim Akram            PAK   1984-2003             356             351
# 2    Waqar Younis            PAK   1989-2003             262             258
# 3      WPUJC Vaas        Asia/SL   1994-2008             322             320
# 4   Shahid Afridi   Asia/ICC/PAK   1996-2015             398             372
#
#    Balls_bowled  Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
# ...

# %%
df['Country'].value_counts() #to see how many unique value in coutnries to plan a separation
# Out:
# PAK             9
# INDIA           9
# AUS             8
# NZ              6
# WI              5
# SL              5
# Asia/INDIA      4
# ENG             4
# Asia/SL         3
# SA              3
# Afr/ICC/SA      2
# Asia/ICC/PAK    2
# BAN             2
# Afr/SA          2
# ENG/ICC         2
# ICC/NZ          2
# AUS/ICC         2
# Asia/PAK        1
# ICC/WI          1
# AFG             1
# ICC/SA          1
# Afr/ZIM         1
# Asia/ICC/SL     1
# Asia/BAN        1
# Name: Country, dtype: int64

# %% [markdown]
# Plan is to remove anything other than country name from the column country (remember WI is counted as a "Country" in ICC event, not an association, before doing that, separate columns  are created thus the data is not lost any if any onformation regarding represting association other than country is required can be seen

# %%
#defining 3 functions separately to find if those association are present in "Country" column or not, in first one conventional method is followed, for next 2 lambda function is used

def asia_check(x):
    if "Asia" in x:
        return "Yes"
    else:
        return "No"

africa_check = lambda x: "Yes" if "Afr" in x else "No"
icc_check = lambda x: "Yes" if "ICC" in x else "No"

# %%
#now creting 3 new columns to keep the data relataed to represting the associations

df['represents_ICC'] = df['Country'].apply(icc_check)
df['represents_Asia'] = df['Country'].apply(asia_check)
df['represents_Africa'] = df['Country'].apply(africa_check)

display(df.head()) #check does it work
# Out:
#        Player_Name       Country Career_Span  Matches_Played  Innings_Bowled  \
# 0  M Muralitharan    Asia/ICC/SL   1993-2011             350             341
# 1     Wasim Akram            PAK   1984-2003             356             351
# 2    Waqar Younis            PAK   1989-2003             262             258
# 3      WPUJC Vaas        Asia/SL   1994-2008             322             320
# 4   Shahid Afridi   Asia/ICC/PAK   1996-2015             398             372
#
#    Balls_bowled  Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
# ...

# %%
#Now try to answer from is new dataset, how many player represent ICC
(df['represents_ICC']=="Yes").sum()
# Out:
# 13

# %% [markdown]
# Now try to make it "nicer", remove association names from the column "Country"

# %%
str_to_remove = ["Asia/", "Afr/", "ICC/", "/ICC",]
new_country_name = []
old_country_name = df["Country"].to_list()

for country in old_country_name:
    for string in str_to_remove:
        country=country.replace(string, "")
    new_country_name.append(country)
print(new_country_name)
# Out:
# ['SL', 'PAK', 'PAK', 'SL', 'PAK', 'SA', 'AUS', 'AUS', 'SL', 'INDIA', 'SL', 'INDIA', 'NZ', 'AUS', 'PAK', 'INDIA', 'BAN', 'INDIA', 'SA', 'SA', 'BAN', 'ENG', 'PAK', 'INDIA', 'SA', 'INDIA', 'PAK', 'NZ', 'AUS', 'ZIM', 'ENG', 'WI', 'WI', 'BAN', 'AUS', 'NZ', 'NZ', 'WI', 'SL', 'SA', 'INDIA', 'AUS', 'AUS', 'WI', 'SA', 'NZ', 'SA', 'INDIA', 'SL', 'PAK', 'PAK', 'PAK', 'PAK', 'ENG', 'SL', 'AUS', 'SA', 'NZ', 'INDIA', 'ENG', 'NZ', 'AUS', 'WI', 'PAK', 'ENG', 'NZ', 'PAK', 'WI', 'INDIA', 'INDIA', 'AUS', 'ENG', 'INDIA', 'SL', 'AFG', 'SL', 'INDIA']

# %%
df["Country"] = new_country_name #replace the old column with new list
display(df.head()) #check the dataset is as per requirement
# Out:
#        Player_Name Country Career_Span  Matches_Played  Innings_Bowled  \
# 0  M Muralitharan       SL   1993-2011             350             341
# 1     Wasim Akram      PAK   1984-2003             356             351
# 2    Waqar Younis      PAK   1989-2003             262             258
# 3      WPUJC Vaas       SL   1994-2008             322             320
# 4   Shahid Afridi      PAK   1996-2015             398             372
#
#    Balls_bowled  Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
# ...

# %% [markdown]
# **Q9: How many different countries are present in this dataset?**
#
# Answering this question is easy now, as the dataset is now rearranged with a well defined "Country" column, so finding the unique value here will answer this question, here the associations will not be counted as country.

# %%
print(len(df["Country"].unique()))
# Out:
# 11

# %% [markdown]
# **Q10: Which player(s) had played for the longest period of time?**
#
# To answer this question, the career_span column need to be rearranged to find the start year and end year of the career, creating two separate column with these value and converting the data type to int will make it easy to find the duration, then simple sorting will help to get the answer.

# %%
# splitting the 'Career_Span' column into two
df[['Start_year', 'End_year']] = df['Career_Span'].str.split("-", expand=True)

# remove old column
df = df.drop("Career_Span", axis=1)

#converting data type of new two columns to int type

df['Start_year'] = df['Start_year'].astype('int') 
df['End_year'] = df['End_year'].astype('int')

#creating new column to find career duration in year
df['Career_duration'] = df['End_year'] - df['Start_year']

display(df.head())
# Out:
#        Player_Name Country  Matches_Played  Innings_Bowled  Balls_bowled  \
# 0  M Muralitharan       SL             350             341         18811
# 1     Wasim Akram      PAK             356             351         18186
# 2    Waqar Younis      PAK             262             258         12698
# 3      WPUJC Vaas       SL             322             320         15775
# 4   Shahid Afridi      PAK             398             372         17670
#
#    Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  Strike_Rate  \
# 0          12326            534            23.08          3.93         35.2
# 1          11812            502            23.52          3.89         36.2
# 2           9919            416            23.84          4.68         30.5
# 3          11014            400            27.53          4.18         39.4
# 4          13632            395            34.51          4.62         44.7
#
#    4_Wicket_haul  5_Wicket_haul represents_ICC represents_Asia  \
# ...

# %%
#now sort the dataset in descending order of Career_duration and find top 10
df.sort_values(by='Career_duration', ascending = False).head(10)
# Out:
#           Player_Name Country  Matches_Played  Innings_Bowled  Balls_bowled  \
# 72      SR Tendulkar    INDIA             463             270          8054
# 10     ST Jayasuriya       SL             445             368         14874
# 66      Shoaib Malik      PAK             287             217          7958
# 62          CH Gayle       WI             301             199          7424
# 4      Shahid Afridi      PAK             398             372         17670
# 20  Mashrafe Mortaza      BAN             220             220         10922
# 1        Wasim Akram      PAK             356             351         18186
# 0     M Muralitharan       SL             350             341         18811
# 50        Imran Khan      PAK             175             153          7461
# 12        DL Vettori       NZ             295             277         14060
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  Strike_Rate  \
# ...

# %% [markdown]
# **Q11: Which player(s) had played for the shortest period of time?**
#
# one line code is enough as the data set is clean and processed.:

# %%
df.sort_values(by='Career_duration', ascending = True).head(10)
# Out:
#          Player_Name Country  Matches_Played  Innings_Bowled  Balls_bowled  \
# 40       BKV Prasad    INDIA             161             160          8129
# 74      Rashid Khan      AFG              80              76          4074
# 73       BAW Mendis       SL              87              84          4154
# 49      Saeed Ajmal      PAK             113             112          6000
# 44       L Klusener       SA             171             164          7336
# 56      Imran Tahir       SA             107             104          5541
# 14  Saqlain Mushtaq      PAK             169             165          8770
# 55       NW Bracken      AUS             116             116          5759
# 58        IK Pathan    INDIA             120             118          5855
# 15       AB Agarkar    INDIA             191             188          9484
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  Strike_Rate  \
# ...

# %% [markdown]
# **Q12: How many Australian Bowlers are present in this dataset?**
#
# **Q13: Is there any Bangladeshi player present in this dataset?**
#
# Both of these questions can be answered with a single line of code.

# %%
df['Country'].value_counts() #to see how many unique value in coutnries to plan a separation
# Out:
# INDIA    13
# PAK      12
# AUS      10
# SL        9
# SA        8
# NZ        8
# ENG       6
# WI        6
# BAN       3
# AFG       1
# ZIM       1
# Name: Country, dtype: int64

# %% [markdown]
# So, there are 10 Australian and 3 Bangladeshi bowlers in the list

# %% [markdown]
# **Q14: Which player had the lowest economy rate?**
#
# sorting the data in respect to economy rate in ascending order

# %%
df.sort_values(by='Economy_Rate', ascending = True).head(10)
# Out:
#         Player_Name Country  Matches_Played  Innings_Bowled  Balls_bowled  \
# 65       RJ Hadlee       NZ             115             112          6182
# 32     CEL Ambrose       WI             176             175          9353
# 67     MD Marshall       WI             136             134          7175
# 5       SM Pollock       SA             303             297         15712
# 25     N Kapil Dev    INDIA             225             221         11202
# 31        CA Walsh       WI             205             204         10822
# 6       GD McGrath      AUS             250             248         12970
# 1      Wasim Akram      PAK             356             351         18186
# 50      Imran Khan      PAK             175             153          7461
# 0   M Muralitharan       SL             350             341         18811
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  Strike_Rate  \
# ...

# %% [markdown]
# **Q15: Which player had the lowest strike rate?**
#
# sorting the data in respect to Strike rate in ascending order

# %%
df.sort_values(by='Strike_Rate', ascending = True).head(10)
# Out:
#          Player_Name Country  Matches_Played  Innings_Bowled  Balls_bowled  \
# 41         MA Starc      AUS              99              99          5099
# 74      Rashid Khan      AFG              80              76          4074
# 73       BAW Mendis       SL              87              84          4154
# 7             B Lee      AUS             221             217         11185
# 60         TA Boult       NZ              93              93          5117
# 14  Saqlain Mushtaq      PAK             169             165          8770
# 2      Waqar Younis      PAK             262             258         12698
# 46         M Morkel       SA             117             114          5760
# 28       MG Johnson      AUS             153             150          7489
# 26    Shoaib Akhtar      PAK             163             162          7764
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  Strike_Rate  \
# ...

# %% [markdown]
# **Q16: Which player had the lowest bowling average?**
#
# sorting the data in respect to bowling average in ascending order

# %%
df.sort_values(by='Bowling_Average', ascending = True).head(10)
# Out:
#          Player_Name Country  Matches_Played  Innings_Bowled  Balls_bowled  \
# 74      Rashid Khan      AFG              80              76          4074
# 65        RJ Hadlee       NZ             115             112          6182
# 19        AA Donald       SA             164             162          8561
# 14  Saqlain Mushtaq      PAK             169             165          8770
# 73       BAW Mendis       SL              87              84          4154
# 6        GD McGrath      AUS             250             248         12970
# 41         MA Starc      AUS              99              99          5099
# 49      Saeed Ajmal      PAK             113             112          6000
# 0    M Muralitharan       SL             350             341         18811
# 7             B Lee      AUS             221             217         11185
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  Strike_Rate  \
# ...

# %% [markdown]
# **Q17: Remove Unnecessary columns if needed.**
#
# This has been done throughout the work, all the column present in current dataset are containing useful information, so better to keep all of those.

# %% [markdown]
# **That is the end of exploration**
